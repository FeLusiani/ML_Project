# %%
import numpy as np
from MLCode.utils import load_cup_data, np_cup_TR
import matplotlib.pyplot as plt

df = load_cup_data()
X, Y = np_cup_TR(df)

print('Data Mean')
print(df.mean(axis=0))
print('Data Variance')
print(df.var(axis=0))
print('Y target')
plt.scatter(Y[:,0],Y[:,1])
plt.show()
# Out:
# Data Mean
# 1     -0.006309
# 2      0.020143
# 3      0.010106
# 4      0.003109
# 5      0.005619
# 6      0.023872
# 7      0.006110
# 8     -0.011253
# 9      0.007343
# 10     0.005921
# 11    48.474973
# 12   -28.571117
# dtype: float64
# Data Variance
# 1       1.083735
# 2       1.093810
# 3       1.083036
# 4       1.098625
# 5       1.054602
# 6       1.112464
# 7       1.105773
# 8       1.094083
# 9       1.071085
# 10      1.118844
# 11    231.607933
# 12    105.472026
# dtype: float64
# Y target
