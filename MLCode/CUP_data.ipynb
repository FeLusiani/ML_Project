# %%
import numpy as np
from MLCode.utils import load_cup_data, np_cup_TR
import matplotlib.pyplot as plt

df = load_cup_data()
matrix = df.to_numpy()
X = matrix[:, :10]
Y = matrix[:, 10:]

print('Data Mean')
print(df.mean(axis=0))
print('Data Variance')
print(df.var(axis=0))
print('Y target')
plt.scatter(Y[:,0],Y[:,1])
plt.show()
# Out:
# Data Mean
# 1     -0.006309
# 2      0.020143
# 3      0.010106
# 4      0.003109
# 5      0.005619
# 6      0.023872
# 7      0.006110
# 8     -0.011253
# 9      0.007343
# 10     0.005921
# 11    48.474973
# 12   -28.571117
# dtype: float64
# Data Variance
# 1       1.083735
# 2       1.093810
# 3       1.083036
# 4       1.098625
# 5       1.054602
# 6       1.112464
# 7       1.105773
# 8       1.094083
# 9       1.071085
# 10      1.118844
# 11    231.607933
# 12    105.472026
# dtype: float64
# Y target

# %%
# This code, used to create the shuffled CUP dataset,
# has been commented in order to avoid accidental execution.
# Since the test / development data split is made on the shuffled data,
# re-shuffling would change the split, leaking (part of) the test data
# into the development process.

# from pathlib import Path
# from MLCode.utils import path_data

# shuffled_cup = path_data / Path('ML_CUP/shuffled_cup.csv')
# df = df.sample(frac=1)
# df.to_csv(shuffled_cup)
